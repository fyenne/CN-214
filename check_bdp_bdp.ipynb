# %%
import pandas as pd

# %%
df = pd.read_clipboard(header = None);df
# Out:
#              0         1      2
# 0   scale_bose  20210610  13621
# 1   scale_bose  20210611  13821
# 2   scale_bose  20210612  13369
# 3   scale_bose  20210613  13310
# 4   scale_bose  20210614  13304
# 5   scale_bose  20210615  13878
# 6   scale_bose  20210616  13732
# 7   scale_bose  20210617  13679
# 8   scale_bose  20210618  13995
# 9   scale_bose  20210619  13722
# 10  scale_bose  20210620  13495
# 11  scale_bose  20210621  13384
# 12  scale_bose  20210622  13720
# 13  scale_bose  20210623  13715
# 14  scale_bose  20210624  14462
# 15  scale_bose  20210625  14551
# 16  scale_bose  20210626  14159
# 17  scale_bose  20210627  13432
# 18  scale_bose  20210628  13265
# 19  scale_bose  20210629  13600
# 20  scale_bose  20210630  13875
# 21  scale_bose  20210701  13629

# %% [markdown]
# ![pic](C:\Users\dscshap3808\Documents\data\CN-214\pics\{CAD04B03-88C6-4637-8FF7-5537B5CC5D2D}.png.jpg)

# %% [markdown]
# ![1_jIhpjYUEXdh2pjBDh2WCzA](C:\Users\dscshap3808\Documents\my_scripts_new\papers\pics_for_paper_folder\1_jIhpjYUEXdh2pjBDh2WCzA.png)
